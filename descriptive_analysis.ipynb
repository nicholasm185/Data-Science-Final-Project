# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
raw = pd.read_csv('laptops.csv', encoding='latin-1')
cleaned = pd.read_csv('supa_clean_data.csv')

# %%
raw
# Out:
#      Manufacturer                           Model Name            Category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#      Screen Size                                      Screen  \
# ...

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              1303 non-null   object
#  1   Model Name                1303 non-null   object
#  2   Category                  1303 non-null   object
#  3   Screen Size               1303 non-null   object
#  4   Screen                    1303 non-null   object
#  5   CPU                       1303 non-null   object
#  6   RAM                       1303 non-null   object
#  7    Storage                  1303 non-null   object
#  8   GPU                       1303 non-null   object
#  9   Operating System          1303 non-null   object
#  10  Operating System Version  1133 non-null   object
#  11  Weight                    1303 non-null   object
#  12  Price (Euros)             1303 non-null   object
# dtypes: object(13)
# memory usage: 132.5+ KB

# %%
cleaned
# Out:
#      Manufacturer                           Model Name            Category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1297       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1298       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1299       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1300           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1301         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#       Screen Size                           GPU  Price (Euros)  \
# ...

# %%
cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302 entries, 0 to 1301
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Manufacturer     1302 non-null   object
#  1   Model Name       1302 non-null   object
#  2   Category         1302 non-null   object
#  3   Screen Size      1302 non-null   float64
#  4   GPU              1302 non-null   object
#  5   Price (Euros)    1302 non-null   int64
#  6   Screen_Type      1302 non-null   object
#  7   RAM              1302 non-null   int64
#  8   SSD              1302 non-null   bool
#  9   HDD              1302 non-null   bool
#  10  HYBRID           1302 non-null   bool
#  11  SSD_CAPACITY     1302 non-null   int64
#  12  HDD_CAPACITY     1302 non-null   int64
#  13  HYBRID_CAPACITY  1302 non-null   int64
#  14  TOTAL_STORAGE    1302 non-null   int64
#  15  Brand            1302 non-null   object
#  16  Clockspeed       1302 non-null   float64
# ...

# %%
plt.hist(cleaned["Price (Euros)"], range=(0,cleaned['Price (Euros)'].max()), bins=12)
plt.title("Histogram of Laptop Prices\n(range of 500 per bar)")
plt.xlabel("Laptop Price (Euros)")
plt.ylabel("Frequency")
plt.show()

# %%
to_plot = [
    cleaned.loc[cleaned['Category'] == 'Ultrabook']['Price (Euros)'],
    cleaned.loc[cleaned['Category'] == 'Notebook']['Price (Euros)'],
    cleaned.loc[cleaned['Category'] == 'Netbook']['Price (Euros)'],
    cleaned.loc[cleaned['Category'] == 'Gaming']['Price (Euros)'],
    cleaned.loc[cleaned['Category'] == '2 in 1 Convertible']['Price (Euros)'],
    cleaned.loc[cleaned['Category'] == 'Workstation']['Price (Euros)']
    ]

plt.figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')

plt.boxplot(to_plot, labels=['Ultrabook', 'Notebook', 'Netbook', 'Gaming', '2 in 1 Convertible', 'Workstation'])
plt.title("Price Ranges for Each Laptop Category")
plt.xlabel("Laptop Category")
plt.ylabel("Price (Euros)")
plt.show()

# %%
plt.figure(1, figsize=(20,10))
plt.subplot(221)
plt.title('RAM')
plt.xlabel("RAM size (GB)")
plt.ylabel("Price (Euros)")
plt.scatter(cleaned['RAM'], cleaned['Price (Euros)'])
plt.subplot(222)
plt.title('TOTAL_STORAGE')
plt.xlabel("Total storage (GB)")
plt.ylabel("Price (Euros)")
plt.scatter(cleaned['TOTAL_STORAGE'], cleaned['Price (Euros)'])
plt.subplot(223)
plt.title('Clockspeed')
plt.xlabel("Clockspeed (GHz)")
plt.ylabel("Price (Euros)")
plt.scatter(cleaned['Clockspeed'], cleaned['Price (Euros)'])
plt.subplot(224)
plt.title('fullRes')
plt.xlabel("fullRes (no. pixels)")
plt.ylabel("Price (Euros)")
plt.scatter(cleaned['fullRes'], cleaned['Price (Euros)'])
plt.show()

# %%
cleaned['Clockspeed'].min()
# Out:
# 0.9

# %%
cleaned['Clockspeed'].max()
# Out:
# 3.6
